# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from finance_byu.summarize import summary
import statsmodels.formula.api as smf
import yfinance as yf

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_parquet("~/Data/BOQ_data.parquet")

df.tail()
# Out:
#              A2ME      BEME  BEME_adj  BEME_ind        CEI       DATE  \
# 3568650  0.211263  0.114912 -0.746238  0.861151 -12.189408 2023-08-31
# 3568651  0.211263  0.114912 -0.750723  0.865635 -11.613183 2023-09-30
# 3568652  0.211263  0.114912 -0.731231  0.846143 -12.752123 2023-10-31
# 3568653  0.211263  0.114912 -0.731231  0.846143  -7.943286 2023-11-30
# 3568654  0.211263  0.114912 -0.731231  0.846143  -9.359996 2023-12-31
#
#                DEC_ME  DEC_SHROUT  Div  Div_ann  ...    s2invt     s2rect  \
# 3568650  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568651  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568652  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568653  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568654  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
#
#             sale    sale_ind   sales_g     sga2s  spread_mean  std_turn  \
# 3568650  81462.0  579615.973  0.513517  0.086187     0.000152  0.708916
# 3568651  81462.0  579615.973  0.513517  0.086187     0.000133  0.465122
# 3568652  81462.0  579615.973  0.513517  0.086187     0.000177  0.531342
# 3568653  81462.0  579615.973  0.513517  0.086187     0.000245  0.614813
# 3568654  81462.0  579615.973  0.513517  0.086187     0.000186  0.599491
#
#               std_vol       suv
# 3568650  2.250092e+07 -1.580970
# 3568651  1.476294e+07 -0.371920
# 3568652  1.686876e+07  0.809301
# 3568653  1.954419e+07  0.278301
# 3568654  1.905735e+07  0.967711
#
# [5 rows x 85 columns]

# %%
# Create initial dataframe. Keep only necessary columns, and generate date variables

keep = ['DATE', 'PERMNO', 'BEME', 'E2P', 'sale', 'ME', 'PRC', 'RET', ]

df = df[keep]

df = df.rename(columns={'DATE':'caldt','PERMNO':'permno','BEME':'beme', 'E2P': 'ep', 'sale': 'sales', 'ME': 'me', 'PRC':'prc', 'RET': 'ret'})

df = df.sort_values(['permno','caldt'])

df['mdt'] = df['caldt'].dt.strftime("%Y-%m")
df['month'] = df['caldt'].dt.strftime("%m")
df['year'] = df['caldt'].dt.strftime("%Y")

# In sample period
start = '1963-04-01'
end = '1990-04-30'

# Out of sample period
# start = '1990-04-30'
# end = '2024-10-07'

df = df[df['caldt'] >= start]
df = df[df['caldt'] <= end]

df = df.reset_index(drop=True)

df.tail()
# Out:
#              caldt   permno  beme  ep  sales           me       prc       ret  \
# 1382626 1985-08-31  93324.0   NaN NaN    NaN  1379.531250  0.093750 -0.142857
# 1382627 1985-09-30  93324.0   NaN NaN    NaN  1149.609375  0.078125 -0.166667
# 1382628 1985-10-31  93324.0   NaN NaN    NaN  1609.453125  0.109375  0.400000
# 1382629 1985-11-30  93324.0   NaN NaN    NaN  1379.531250  0.093750 -0.142857
# 1382630 1985-12-31  93324.0   NaN NaN    NaN          NaN  0.093750 -0.142857
#
#              mdt month  year
# 1382626  1985-08    08  1985
# 1382627  1985-09    09  1985
# 1382628  1985-10    10  1985
# 1382629  1985-11    11  1985
# 1382630  1985-12    12  1985

# %% [markdown]
# Feature Generation

# %%
# Generate features from the last 12 months

formation_period = 12 # months

# 1 month sales growth
df['sg'] = df.groupby("permno")['sales'].pct_change(fill_method=None)

# Log 1 months sales growth
df['log_sg'] = np.log(1+df['sg'])

# Past 1 year log sales growth
df[f'log_sg_{formation_period}'] = df.groupby('permno').rolling(formation_period,formation_period)['log_sg'].sum().reset_index(drop=True)

df.tail()
# Out:
# /Users/andrew/Projects/Quant/mean_reversion/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/andrew/Projects/Quant/mean_reversion/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#              caldt   permno  beme  ep  sales           me       prc       ret  \
# 1382626 1985-08-31  93324.0   NaN NaN    NaN  1379.531250  0.093750 -0.142857
# 1382627 1985-09-30  93324.0   NaN NaN    NaN  1149.609375  0.078125 -0.166667
# 1382628 1985-10-31  93324.0   NaN NaN    NaN  1609.453125  0.109375  0.400000
# 1382629 1985-11-30  93324.0   NaN NaN    NaN  1379.531250  0.093750 -0.142857
# 1382630 1985-12-31  93324.0   NaN NaN    NaN          NaN  0.093750 -0.142857
#
#              mdt month  year  sg  log_sg  log_sg_12
# 1382626  1985-08    08  1985 NaN     NaN        NaN
# 1382627  1985-09    09  1985 NaN     NaN        NaN
# 1382628  1985-10    10  1985 NaN     NaN        NaN
# 1382629  1985-11    11  1985 NaN     NaN        NaN
# 1382630  1985-12    12  1985 NaN     NaN        NaN

# %%
# Generate target variable

# Log 1 month return
df['log_ret'] = np.log(1 + df['ret'])

holding_period = 1 # months

# 12 month holding period return
df[f'ret_{holding_period}'] = df.groupby('permno').rolling(holding_period,holding_period)['log_ret'].sum().reset_index(drop=True)
df[f'ret_{holding_period}'] = df.groupby('permno')[f'ret_{holding_period}'].shift(-(holding_period-1))

df.tail()
# Out:
#              caldt   permno  beme  ep  sales           me       prc       ret  \
# 1382626 1985-08-31  93324.0   NaN NaN    NaN  1379.531250  0.093750 -0.142857
# 1382627 1985-09-30  93324.0   NaN NaN    NaN  1149.609375  0.078125 -0.166667
# 1382628 1985-10-31  93324.0   NaN NaN    NaN  1609.453125  0.109375  0.400000
# 1382629 1985-11-30  93324.0   NaN NaN    NaN  1379.531250  0.093750 -0.142857
# 1382630 1985-12-31  93324.0   NaN NaN    NaN          NaN  0.093750 -0.142857
#
#              mdt month  year  sg  log_sg  log_sg_12   log_ret     ret_1
# 1382626  1985-08    08  1985 NaN     NaN        NaN -0.154151 -0.154151
# 1382627  1985-09    09  1985 NaN     NaN        NaN -0.182322 -0.182322
# 1382628  1985-10    10  1985 NaN     NaN        NaN  0.336472  0.336472
# 1382629  1985-11    11  1985 NaN     NaN        NaN -0.154151 -0.154151
# 1382630  1985-12    12  1985 NaN     NaN        NaN -0.154151 -0.154151

# %%
# Lag all formation variables by 1 month
df['ep_lag'] = df.groupby('permno')['ep'].shift(1)
df['sg_lag'] = df.groupby('permno')[f'log_sg_{formation_period}'].shift(1)
df['prc_lag'] = df.groupby('permno')['prc'].shift(1)

# Remove stocks that don't have formation variables and low priced stocks
df = df.query("ep_lag == ep_lag and sg_lag == sg_lag and prc_lag >= 5").reset_index(drop=True)

df.tail()
# Out:
#             caldt   permno      beme        ep   sales          me      prc  \
# 706244 1990-03-31  93236.0       NaN -0.211454   0.800  35350.0000  12.5000
# 706245 1990-04-30  93236.0       NaN -0.211454   0.800  47722.5000  16.8750
# 706246 1987-09-30  93287.0  1.147422 -0.451362  42.952  47043.5625   6.1875
# 706247 1987-10-31  93287.0  1.147422 -0.451362  42.952  22809.0000   3.0000
# 706248 1987-08-31  93316.0  1.244688  0.036332  90.400  11961.0000   4.5000
#
#              ret      mdt month  year   sg  log_sg  log_sg_12   log_ret  \
# 706244  0.639344  1990-03    03  1990  0.0     0.0   0.980829  0.494296
# 706245  0.350000  1990-04    04  1990  0.0     0.0   0.980829  0.300105
# 706246  0.053191  1987-09    09  1987  0.0     0.0  -0.435674  0.051825
# 706247 -0.515152  1987-10    10  1987  0.0     0.0  -0.435674 -0.723919
# 706248 -0.100000  1987-08    08  1987  0.0     0.0   0.142063 -0.105361
#
#            ret_1    ep_lag    sg_lag  prc_lag
# 706244  0.494296 -0.211454  0.980829   7.6250
# 706245  0.300105 -0.211454  0.980829  12.5000
# 706246  0.051825 -0.451362 -0.435674   5.8750
# 706247 -0.723919 -0.451362 -0.435674   6.1875
# 706248 -0.105361  0.036332  0.142063   5.0000

# %% [markdown]
# ### Portfolio Formation

# %%
# Create quantiles based off of b/m lag and sales growth lag using independent sorts
df['ep_bins'] = df.groupby("mdt")['ep_lag'].transform(lambda x: pd.qcut(x, 3, labels=False))
df['sg_bins'] = df.groupby("mdt")['sg_lag'].transform(lambda x: pd.qcut(x, 3, labels=False))

df.tail()
# Out:
#             caldt   permno      beme        ep   sales          me      prc  \
# 706244 1990-03-31  93236.0       NaN -0.211454   0.800  35350.0000  12.5000
# 706245 1990-04-30  93236.0       NaN -0.211454   0.800  47722.5000  16.8750
# 706246 1987-09-30  93287.0  1.147422 -0.451362  42.952  47043.5625   6.1875
# 706247 1987-10-31  93287.0  1.147422 -0.451362  42.952  22809.0000   3.0000
# 706248 1987-08-31  93316.0  1.244688  0.036332  90.400  11961.0000   4.5000
#
#              ret      mdt month  ...   sg  log_sg  log_sg_12   log_ret  \
# 706244  0.639344  1990-03    03  ...  0.0     0.0   0.980829  0.494296
# 706245  0.350000  1990-04    04  ...  0.0     0.0   0.980829  0.300105
# 706246  0.053191  1987-09    09  ...  0.0     0.0  -0.435674  0.051825
# 706247 -0.515152  1987-10    10  ...  0.0     0.0  -0.435674 -0.723919
# 706248 -0.100000  1987-08    08  ...  0.0     0.0   0.142063 -0.105361
#
#            ret_1    ep_lag    sg_lag  prc_lag  ep_bins  sg_bins
# 706244  0.494296 -0.211454  0.980829   7.6250        0        2
# 706245  0.300105 -0.211454  0.980829  12.5000        0        2
# 706246  0.051825 -0.451362 -0.435674   5.8750        0        0
# 706247 -0.723919 -0.451362 -0.435674   6.1875        0        0
# 706248 -0.105361  0.036332  0.142063   5.0000        0        1
#
# [5 rows x 21 columns]

# %%
# Group stocks by year and bins
port = df.groupby(['mdt', 'ep_bins', 'sg_bins'])[f'ret_{holding_period}'].mean().unstack(level=['ep_bins', 'sg_bins'])

# Drop rows with no holding period returns
port = port.dropna()

# Value portfolio is high b/m and low sg
# Glamor portfolio is low b/m and high sg
# Create a spread portfolio with long value and short glamor stocks
port['spread'] = port[2][0] - port[0][2]

port_100 = port * 100

port_100.tail()
# Out:
# ep_bins         0                              1                       \
# sg_bins         0         1          2         0         1          2
# mdt
# 1989-12 -1.069849  0.132313   0.142133  1.186751  1.258842   0.267692
# 1990-01 -8.469648 -7.420366 -11.149854 -6.559492 -9.558665 -10.238659
# 1990-02  0.647505  2.809143   3.121308  1.110040  0.732979   2.094514
# 1990-03  2.208770  3.072597   4.317336  2.407679  2.738588   3.374355
# 1990-04 -4.115340 -2.677478  -4.527582 -2.732230 -2.888676  -3.319395
#
# ep_bins         2                        spread
# sg_bins         0         1         2
# mdt
# 1989-12  0.121615 -1.062402 -0.839497 -0.020518
# 1990-01 -7.051596 -8.939138 -7.894368  4.098259
# 1990-02  1.636635  1.783334  2.549971 -1.484673
# 1990-03  1.261996  1.962622  3.364541 -3.055339
# 1990-04 -5.067472 -4.233380 -4.092460 -0.539890

# %% [markdown]
# ### Portfolio Summary Table

# %%
# Portfolio summary table

(summary(port_100).loc[['mean','std','tstat']]).round(3)
# Out:
# ep_bins      0                    1                    2               spread
# sg_bins      0      1      2      0      1      2      0      1      2
# mean     0.232  0.292 -0.161  0.810  0.789  0.365  1.087  1.088  0.831  1.248
# std      6.473  6.041  7.323  5.278  5.289  6.327  5.195  5.126  6.016  3.522
# tstat    0.634  0.852 -0.388  2.709  2.634  1.018  3.695  3.751  2.441  6.257

# %% [markdown]
# ### Backtest

# %%
# Create backtest with monthly returns

backtest = port['spread'].reset_index().copy()

backtest = backtest.rename(columns={'spread': 'log_ret'})

# Cuummulative sum the log returns
backtest['cum_ret'] = backtest['log_ret'].cumsum()

# Create date column for plotting purposes
backtest['caldt'] = pd.to_datetime(backtest['mdt'])

backtest
# Out:
#          mdt   log_ret   cum_ret      caldt
# 0    1964-05  0.004791  0.004791 1964-05-01
# 1    1964-06 -0.012833 -0.008042 1964-06-01
# 2    1964-07  0.011534  0.003491 1964-07-01
# 3    1964-08  0.018320  0.021811 1964-08-01
# 4    1964-09 -0.002932  0.018879 1964-09-01
# ..       ...       ...       ...        ...
# 307  1989-12 -0.000205  3.902075 1989-12-01
# 308  1990-01  0.040983  3.943058 1990-01-01
# 309  1990-02 -0.014847  3.928211 1990-02-01
# 310  1990-03 -0.030553  3.897658 1990-03-01
# 311  1990-04 -0.005399  3.892259 1990-04-01
#
# [312 rows x 4 columns]

# %%
# Pull in benchmark data for plotting purposes

bmk = yf.download('^GSPC', start=start, end=end)

# Data preparation
bmk = bmk.reset_index()

bmk = bmk.rename(columns={'Date': 'caldt', 'Adj Close': 'prc'})

bmk = bmk[['caldt', 'prc']]

bmk['mdt'] = bmk['caldt'].dt.strftime("%Y-%m")

# Aggregate to monthly level
bmk = bmk.groupby('mdt').agg({'prc': 'first'}).reset_index()

bmk['caldt'] = pd.to_datetime(bmk['mdt'])

# Return metrics for plotting
bmk['ret'] = bmk['prc'].pct_change()
bmk['log_ret'] = np.log(1 + bmk['ret'])
bmk['cum_ret'] = bmk['log_ret'].cumsum()

bmk
# Out:
# [*********************100%***********************]  1 of 1 completed
#          mdt         prc      caldt       ret   log_ret   cum_ret
# 0    1963-04   66.849998 1963-04-01       NaN       NaN       NaN
# 1    1963-05   69.970001 1963-05-01  0.046672  0.045615  0.045615
# 2    1963-06   70.690002 1963-06-01  0.010290  0.010238  0.055853
# 3    1963-07   68.860001 1963-07-01 -0.025888 -0.026229  0.029624
# 4    1963-08   69.070000 1963-08-01  0.003050  0.003045  0.032669
# ..       ...         ...        ...       ...       ...       ...
# 320  1989-12  350.630005 1989-12-01  0.027638  0.027263  1.657280
# 321  1990-01  359.690002 1990-01-01  0.025839  0.025511  1.682791
# 322  1990-02  328.790009 1990-02-01 -0.085907 -0.089823  1.592968
# 323  1990-03  332.739990 1990-03-01  0.012014  0.011942  1.604910
# 324  1990-04  338.700012 1990-04-01  0.017912  0.017753  1.622664
#
# [325 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(backtest['caldt'], backtest['cum_ret'] * 100, label='Contrarian Strategy', color='green')
plt.plot(bmk['caldt'], bmk['cum_ret'] * 100, label='S&P 500 (^GSPC)', color='orange')
plt.title(f"In Sample E/P + GS Backtest ({start} - {end})")
plt.ylabel("Cummulative Log Return (%)")
plt.legend()
plt.show()

# %%
# Calculate napkin sharpe ratio using monthly returns

numerator = backtest['log_ret'].mean()
denominator = backtest['log_ret'].std()
scale = 12 / np.sqrt(12)

sharpe = numerator / denominator * scale

print(f"Sharpe Ratio: {round(sharpe,2)}")
# Out:
# Sharpe Ratio: 1.23

# %% [markdown]
# ### 5 Factor Model Decomposition

# %%
# Pull in fama french 5 factors
fac = pd.read_csv("~/Data/fama_5_factors.csv")

# Create mdt variable for merging
fac['mdt'] = pd.to_datetime(fac['DATE'].astype(str), format='%Y%m').dt.strftime("%Y-%m")

fac
# Out:
#        DATE  Mkt-RF   SMB   HML   RMW   CMA    RF      mdt
# 0    196307   -0.39 -0.41 -0.97  0.68 -1.18  0.27  1963-07
# 1    196308    5.07 -0.80  1.80  0.36 -0.35  0.25  1963-08
# 2    196309   -1.57 -0.52  0.13 -0.71  0.29  0.27  1963-09
# 3    196310    2.53 -1.39 -0.10  2.80 -2.01  0.29  1963-10
# 4    196311   -0.85 -0.88  1.75 -0.51  2.24  0.27  1963-11
# ..      ...     ...   ...   ...   ...   ...   ...      ...
# 729  202404   -4.67 -2.56 -0.52  1.48 -0.30  0.47  2024-04
# 730  202405    4.34  0.76 -1.66  2.98 -3.07  0.44  2024-05
# 731  202406    2.77 -4.37 -3.31  0.51 -1.78  0.41  2024-06
# 732  202407    1.24  8.28  5.73  0.22  0.43  0.45  2024-07
# 733  202408    1.61 -3.65 -1.12  0.85  0.86  0.48  2024-08
#
# [734 rows x 8 columns]

# %%
# Merge port and fac 
merge = pd.merge(backtest, fac, on='mdt', how='inner')

# Drop unecessary columns
merge = merge.drop(columns=['cum_ret', 'caldt', 'DATE'])

merge['log_ret'] = merge['log_ret'] * 100

merge['xs_log_ret'] = merge['log_ret'] - merge['RF']

merge = merge.rename(columns={'Mkt-RF': 'XS_MKT'})

merge
# Out:
#          mdt   log_ret  XS_MKT   SMB   HML   RMW   CMA    RF  xs_log_ret
# 0    1964-05  0.479073    1.42 -0.63  1.86 -0.16  0.17  0.26    0.219073
# 1    1964-06 -1.283318    1.27  0.29  0.62 -0.28 -0.17  0.30   -1.583318
# 2    1964-07  1.153358    1.74  0.50  0.75  0.08  1.91  0.30    0.853358
# 3    1964-08  1.832006   -1.44  0.41  0.08  0.12  0.35  0.28    1.552006
# 4    1964-09 -0.293175    2.69 -0.34  1.70 -0.56  0.62  0.28   -0.573175
# ..       ...       ...     ...   ...   ...   ...   ...   ...         ...
# 307  1989-12 -0.020518    1.16 -2.27  0.16 -0.07  1.42  0.61   -0.630518
# 308  1990-01  4.098259   -7.85 -1.31  0.85 -1.17  1.35  0.57    3.528259
# 309  1990-02 -1.484673    1.11  1.17  0.64 -0.03 -0.66  0.57   -2.054673
# 310  1990-03 -3.055339    1.83  1.62 -2.92  2.04 -1.02  0.64   -3.695339
# 311  1990-04 -0.539890   -3.36 -0.33 -2.59  1.78 -0.98  0.69   -1.229890
#
# [312 rows x 9 columns]

# %%
# Run a single factor model regression
model = smf.ols("xs_log_ret ~ XS_MKT", data=merge).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             xs_log_ret   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     173.8
# Date:                Tue, 08 Oct 2024   Prob (F-statistic):           8.30e-32
# Time:                        08:27:18   Log-Likelihood:                -764.24
# No. Observations:                 312   AIC:                             1532.
# Df Residuals:                     310   BIC:                             1540.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8388      0.160      5.255      0.000       0.525       1.153
# XS_MKT        -0.4555      0.035    -13.182      0.000      -0.524      -0.388
# ==============================================================================
# Omnibus:                       24.634   Durbin-Watson:                   1.600
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.168
# Skew:                           0.414   Prob(JB):                     7.75e-12
# Kurtosis:                       4.803   Cond. No.                         4.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Run a 5 factor model regression
model = smf.ols("xs_log_ret ~ XS_MKT + SMB + HML + RMW + CMA", data=merge).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             xs_log_ret   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     204.7
# Date:                Tue, 08 Oct 2024   Prob (F-statistic):           2.47e-95
# Time:                        08:27:18   Log-Likelihood:                -604.53
# No. Observations:                 312   AIC:                             1221.
# Df Residuals:                     306   BIC:                             1244.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2594      0.106      2.456      0.015       0.052       0.467
# XS_MKT        -0.2066      0.025     -8.407      0.000      -0.255      -0.158
# SMB           -0.1322      0.036     -3.713      0.000      -0.202      -0.062
# HML            0.8409      0.059     14.365      0.000       0.726       0.956
# RMW            0.2871      0.081      3.537      0.000       0.127       0.447
# CMA            0.3251      0.084      3.883      0.000       0.160       0.490
# ==============================================================================
# Omnibus:                       29.886   Durbin-Watson:                   1.703
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.401
# Skew:                           0.489   Prob(JB):                     6.29e-15
# Kurtosis:                       5.018   Cond. No.                         6.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# True sharpe ratio (includes the risk free rate)

numerator = (merge['log_ret'] - merge['RF']).mean()
denominator = merge['log_ret'].std()
scale = 12 / np.sqrt(12)

sharpe = numerator / denominator * scale

print(f"Sharpe Ratio: {round(sharpe,2)}")
# Out:
# Sharpe Ratio: 0.67

# %%
# Market sharpe over the same period

numerator = fac['Mkt-RF'].mean()
denominator = (fac['Mkt-RF'] + fac['RF']).std()
scale = 12 / np.sqrt(12)

sharpe = numerator / denominator * scale

print(f"Market Sharpe Ratio: {round(sharpe, 2)}")
# Out:
# Market Sharpe Ratio: 0.45
