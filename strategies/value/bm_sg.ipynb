# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from finance_byu.summarize import summary
import statsmodels.formula.api as smf
import yfinance as yf

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_parquet("~/Data/BOQ_data.parquet")

df.tail()
# Out:
#              A2ME      BEME  BEME_adj  BEME_ind        CEI       DATE  \
# 3568650  0.211263  0.114912 -0.746238  0.861151 -12.189408 2023-08-31
# 3568651  0.211263  0.114912 -0.750723  0.865635 -11.613183 2023-09-30
# 3568652  0.211263  0.114912 -0.731231  0.846143 -12.752123 2023-10-31
# 3568653  0.211263  0.114912 -0.731231  0.846143  -7.943286 2023-11-30
# 3568654  0.211263  0.114912 -0.731231  0.846143  -9.359996 2023-12-31
#
#                DEC_ME  DEC_SHROUT  Div  Div_ann  ...    s2invt     s2rect  \
# 3568650  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568651  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568652  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568653  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
# 3568654  3.897415e+08   3164000.0  0.0      0.0  ...  6.344887  26.084534
#
#             sale    sale_ind   sales_g     sga2s  spread_mean  std_turn  \
# 3568650  81462.0  579615.973  0.513517  0.086187     0.000152  0.708916
# 3568651  81462.0  579615.973  0.513517  0.086187     0.000133  0.465122
# 3568652  81462.0  579615.973  0.513517  0.086187     0.000177  0.531342
# 3568653  81462.0  579615.973  0.513517  0.086187     0.000245  0.614813
# 3568654  81462.0  579615.973  0.513517  0.086187     0.000186  0.599491
#
#               std_vol       suv
# 3568650  2.250092e+07 -1.580970
# 3568651  1.476294e+07 -0.371920
# 3568652  1.686876e+07  0.809301
# 3568653  1.954419e+07  0.278301
# 3568654  1.905735e+07  0.967711
#
# [5 rows x 85 columns]

# %%
# Create initial dataframe. Keep only necessary columns, and generate date variables

keep = ['DATE', 'PERMNO', 'BEME', 'E2P', 'sale', 'ME', 'PRC', 'RET', ]

df = df[keep]

df = df.rename(columns={'DATE':'caldt','PERMNO':'permno','BEME':'beme', 'E2P': 'ep', 'sale': 'sales', 'ME': 'me', 'PRC':'prc', 'RET': 'ret'})

df = df.sort_values(['permno','caldt'])

df['mdt'] = df['caldt'].dt.strftime("%Y-%m")
df['month'] = df['caldt'].dt.strftime("%m")
df['year'] = df['caldt'].dt.strftime("%Y")

# In sample period
# start = '1963-04-01'
# end = '1990-04-30'
start = '1990-04-30'
end = '2024-10-07'
df = df[df['caldt'] >= start]
df = df[df['caldt'] <= end]

df = df.reset_index(drop=True)

df.tail()
# Out:
#              caldt   permno      beme        ep    sales            me  \
# 2044042 2023-08-31  93436.0  0.114912  0.032216  81462.0  8.191443e+08
# 2044043 2023-09-30  93436.0  0.114912  0.032216  81462.0  7.954494e+08
# 2044044 2023-10-31  93436.0  0.114912  0.032216  81462.0  6.384545e+08
# 2044045 2023-11-30  93436.0  0.114912  0.032216  81462.0  7.631954e+08
# 2044046 2023-12-31  93436.0  0.114912  0.032216  81462.0  7.898983e+08
#
#                 prc       ret      mdt month  year
# 2044042  258.079987 -0.034962  2023-08    08  2023
# 2044043  250.220001 -0.030456  2023-09    09  2023
# 2044044  200.839996 -0.197346  2023-10    10  2023
# 2044045  240.080002  0.195379  2023-11    11  2023
# 2044046  248.479996  0.034988  2023-12    12  2023

# %% [markdown]
# Feature Generation

# %%
# Generate features from the last 12 months

formation_period = 12 # months

# 1 month sales growth
df['sg'] = df.groupby("permno")['sales'].pct_change(fill_method=None)

# Log 1 months sales growth
df['log_sg'] = np.log(1+df['sg'])

# Past 1 year log sales growth
df[f'log_sg_{formation_period}'] = df.groupby('permno').rolling(formation_period,formation_period)['log_sg'].sum().reset_index(drop=True)

df.tail()
# Out:
# /Users/andrew/Projects/Quant/mean_reversion/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/andrew/Projects/Quant/mean_reversion/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#              caldt   permno      beme        ep    sales            me  \
# 2044042 2023-08-31  93436.0  0.114912  0.032216  81462.0  8.191443e+08
# 2044043 2023-09-30  93436.0  0.114912  0.032216  81462.0  7.954494e+08
# 2044044 2023-10-31  93436.0  0.114912  0.032216  81462.0  6.384545e+08
# 2044045 2023-11-30  93436.0  0.114912  0.032216  81462.0  7.631954e+08
# 2044046 2023-12-31  93436.0  0.114912  0.032216  81462.0  7.898983e+08
#
#                 prc       ret      mdt month  year   sg  log_sg  log_sg_12
# 2044042  258.079987 -0.034962  2023-08    08  2023  0.0     0.0   0.414436
# 2044043  250.220001 -0.030456  2023-09    09  2023  0.0     0.0   0.414436
# 2044044  200.839996 -0.197346  2023-10    10  2023  0.0     0.0   0.414436
# 2044045  240.080002  0.195379  2023-11    11  2023  0.0     0.0   0.414436
# 2044046  248.479996  0.034988  2023-12    12  2023  0.0     0.0   0.414436

# %%
# Generate target variable

# Log 1 month return
df['log_ret'] = np.log(1 + df['ret'])

holding_period = 12 # months

# 12 month holding period return
df[f'ret_{holding_period}'] = df.groupby('permno').rolling(holding_period,holding_period)['log_ret'].sum().reset_index(drop=True)
df[f'ret_{holding_period}'] = df.groupby('permno')[f'ret_{holding_period}'].shift(-(holding_period-1))

df.tail()
# Out:
#              caldt   permno      beme        ep    sales            me  \
# 2044042 2023-08-31  93436.0  0.114912  0.032216  81462.0  8.191443e+08
# 2044043 2023-09-30  93436.0  0.114912  0.032216  81462.0  7.954494e+08
# 2044044 2023-10-31  93436.0  0.114912  0.032216  81462.0  6.384545e+08
# 2044045 2023-11-30  93436.0  0.114912  0.032216  81462.0  7.631954e+08
# 2044046 2023-12-31  93436.0  0.114912  0.032216  81462.0  7.898983e+08
#
#                 prc       ret      mdt month  year   sg  log_sg  log_sg_12  \
# 2044042  258.079987 -0.034962  2023-08    08  2023  0.0     0.0   0.414436
# 2044043  250.220001 -0.030456  2023-09    09  2023  0.0     0.0   0.414436
# 2044044  200.839996 -0.197346  2023-10    10  2023  0.0     0.0   0.414436
# 2044045  240.080002  0.195379  2023-11    11  2023  0.0     0.0   0.414436
# 2044046  248.479996  0.034988  2023-12    12  2023  0.0     0.0   0.414436
#
#           log_ret  ret_12
# 2044042 -0.035588     NaN
# 2044043 -0.030929     NaN
# 2044044 -0.219832     NaN
# 2044045  0.178464     NaN
# 2044046  0.034390     NaN

# %%
# Lag all formation variables by 1 month
df['beme_lag'] = df.groupby('permno')['beme'].shift(1)
df['sg_lag'] = df.groupby('permno')[f'log_sg_{formation_period}'].shift(1)
df['prc_lag'] = df.groupby('permno')['prc'].shift(1)

# Remove stocks that don't have formation variables and low priced stocks
df = df.query("beme_lag == beme_lag and sg_lag == sg_lag and prc_lag >= 5").reset_index(drop=True)

df.tail()
# Out:
#              caldt   permno      beme        ep    sales            me  \
# 1174594 2023-08-31  93436.0  0.114912  0.032216  81462.0  8.191443e+08
# 1174595 2023-09-30  93436.0  0.114912  0.032216  81462.0  7.954494e+08
# 1174596 2023-10-31  93436.0  0.114912  0.032216  81462.0  6.384545e+08
# 1174597 2023-11-30  93436.0  0.114912  0.032216  81462.0  7.631954e+08
# 1174598 2023-12-31  93436.0  0.114912  0.032216  81462.0  7.898983e+08
#
#                 prc       ret      mdt month  year   sg  log_sg  log_sg_12  \
# 1174594  258.079987 -0.034962  2023-08    08  2023  0.0     0.0   0.414436
# 1174595  250.220001 -0.030456  2023-09    09  2023  0.0     0.0   0.414436
# 1174596  200.839996 -0.197346  2023-10    10  2023  0.0     0.0   0.414436
# 1174597  240.080002  0.195379  2023-11    11  2023  0.0     0.0   0.414436
# 1174598  248.479996  0.034988  2023-12    12  2023  0.0     0.0   0.414436
#
#           log_ret  ret_12  beme_lag    sg_lag     prc_lag
# 1174594 -0.035588     NaN  0.114912  0.414436  267.429993
# 1174595 -0.030929     NaN  0.114912  0.414436  258.079987
# 1174596 -0.219832     NaN  0.114912  0.414436  250.220001
# 1174597  0.178464     NaN  0.114912  0.414436  200.839996
# 1174598  0.034390     NaN  0.114912  0.414436  240.080002

# %% [markdown]
# ### Portfolio Formation

# %%
# Create quantiles based off of b/m lag and sales growth lag using independent sorts
df['beme_bins'] = df.groupby("mdt")['beme_lag'].transform(lambda x: pd.qcut(x, 3, labels=False))
df['sg_bins'] = df.groupby("mdt")['sg_lag'].transform(lambda x: pd.qcut(x, 3, labels=False))

df.tail()
# Out:
#              caldt   permno      beme        ep    sales            me  \
# 1174594 2023-08-31  93436.0  0.114912  0.032216  81462.0  8.191443e+08
# 1174595 2023-09-30  93436.0  0.114912  0.032216  81462.0  7.954494e+08
# 1174596 2023-10-31  93436.0  0.114912  0.032216  81462.0  6.384545e+08
# 1174597 2023-11-30  93436.0  0.114912  0.032216  81462.0  7.631954e+08
# 1174598 2023-12-31  93436.0  0.114912  0.032216  81462.0  7.898983e+08
#
#                 prc       ret      mdt month  ...   sg  log_sg  log_sg_12  \
# 1174594  258.079987 -0.034962  2023-08    08  ...  0.0     0.0   0.414436
# 1174595  250.220001 -0.030456  2023-09    09  ...  0.0     0.0   0.414436
# 1174596  200.839996 -0.197346  2023-10    10  ...  0.0     0.0   0.414436
# 1174597  240.080002  0.195379  2023-11    11  ...  0.0     0.0   0.414436
# 1174598  248.479996  0.034988  2023-12    12  ...  0.0     0.0   0.414436
#
#           log_ret  ret_12  beme_lag    sg_lag     prc_lag  beme_bins  sg_bins
# 1174594 -0.035588     NaN  0.114912  0.414436  267.429993          0        2
# 1174595 -0.030929     NaN  0.114912  0.414436  258.079987          0        2
# 1174596 -0.219832     NaN  0.114912  0.414436  250.220001          0        2
# 1174597  0.178464     NaN  0.114912  0.414436  200.839996          0        2
# 1174598  0.034390     NaN  0.114912  0.414436  240.080002          0        2
#
# [5 rows x 21 columns]

# %%
# Create portfolio dataframe with only january month data
port = df[df['month'] == '01'].copy()

# Group stocks by year and bins
port = port.groupby(['year', 'beme_bins', 'sg_bins'])[f'ret_{holding_period}'].mean().unstack(level=['beme_bins', 'sg_bins'])

# Drop rows with no holding period returns
port = port.dropna()

# Value portfolio is high b/m and low sg
# Glamor portfolio is low b/m and high sg
# Create a spread portfolio with long value and short glamor stocks
port['spread'] = port[2][0] - port[0][2]

port['spread'] = port['spread'] * 100

port.tail()
# Out:
# beme_bins         0                             1                      \
# sg_bins           0         1         2         0         1         2
# year
# 2019       0.149080  0.235617  0.198530  0.125722  0.190631  0.164660
# 2020       0.175807  0.181202  0.329058  0.013420  0.009003 -0.027363
# 2021       0.056399  0.154858 -0.099148  0.195464  0.170540  0.088332
# 2022      -0.474566 -0.337910 -0.548848 -0.210178 -0.184508 -0.337928
# 2023       0.016170  0.139405  0.079783 -0.002105  0.078431  0.119505
#
# beme_bins         2                         spread
# sg_bins           0         1         2
# year
# 2019       0.078249  0.167692  0.084939 -12.028086
# 2020      -0.059035 -0.059084 -0.131108 -38.809332
# 2021       0.216964  0.264182  0.261746  31.611139
# 2022      -0.082411 -0.114664 -0.160708  46.643714
# 2023       0.029206  0.037902  0.019670  -5.057676

# %% [markdown]
# ### Portfolio Summary Table

# %%
# Portfolio summary table

# (summary(port).loc[['count','mean','std','tstat']] * 100).round(3)

(summary(port).loc[['mean','std','tstat']]).round(3)
# Out:
# beme_bins      0                    1                    2                \
# sg_bins        0      1      2      0      1      2      0      1      2
# mean      -0.038  0.037 -0.060  0.029  0.052 -0.010  0.036  0.062  0.004
# std        0.223  0.184  0.270  0.190  0.166  0.231  0.207  0.198  0.237
# tstat     -0.965  1.146 -1.258  0.853  1.767 -0.238  0.986  1.773  0.101
#
# beme_bins  spread
# sg_bins
# mean        9.625
# std        21.111
# tstat       2.579

# %% [markdown]
# ### Backtest

# %%
# Create backtest with yearly returns

backtest_y = port.copy()
backtest_y.index = pd.to_datetime(backtest_y.index)
backtest_y['cum_ret'] = backtest_y['spread'].cumsum()

backtest_y.tail()
# Out:
# beme_bins          0                             1                      \
# sg_bins            0         1         2         0         1         2
# year
# 2019-01-01  0.149080  0.235617  0.198530  0.125722  0.190631  0.164660
# 2020-01-01  0.175807  0.181202  0.329058  0.013420  0.009003 -0.027363
# 2021-01-01  0.056399  0.154858 -0.099148  0.195464  0.170540  0.088332
# 2022-01-01 -0.474566 -0.337910 -0.548848 -0.210178 -0.184508 -0.337928
# 2023-01-01  0.016170  0.139405  0.079783 -0.002105  0.078431  0.119505
#
# beme_bins          2                         spread     cum_ret
# sg_bins            0         1         2
# year
# 2019-01-01  0.078249  0.167692  0.084939 -12.028086  273.606205
# 2020-01-01 -0.059035 -0.059084 -0.131108 -38.809332  234.796873
# 2021-01-01  0.216964  0.264182  0.261746  31.611139  266.408012
# 2022-01-01 -0.082411 -0.114664 -0.160708  46.643714  313.051726
# 2023-01-01  0.029206  0.037902  0.019670  -5.057676  307.994050

# %%
plt.plot(backtest_y.index,backtest_y['cum_ret'])
plt.title("Backtest w/ Yearly Returns")
plt.ylabel("Cummulative Log Return")
plt.show()

# %%
# Create backtest with monthly returns

backtest_m = df.groupby(['mdt','beme_bins','sg_bins'])['log_ret'].mean().unstack(level=['beme_bins','sg_bins'])

backtest_m['spread'] = backtest_m[2][0] - backtest_m[0][2]

backtest_m = backtest_m.dropna()

backtest_m = backtest_m['spread'].reset_index()

backtest_m = backtest_m.rename(columns={'spread': 'log_ret'})

backtest_m['cum_ret'] = backtest_m['log_ret'].cumsum()

backtest_m['caldt'] = pd.to_datetime(backtest_m['mdt'])

backtest_m
# Out:
#          mdt   log_ret   cum_ret      caldt
# 0    1991-05 -0.002955 -0.002955 1991-05-01
# 1    1991-06  0.041586  0.038631 1991-06-01
# 2    1991-07 -0.016260  0.022371 1991-07-01
# 3    1991-08 -0.018842  0.003529 1991-08-01
# 4    1991-09 -0.020187 -0.016658 1991-09-01
# ..       ...       ...       ...        ...
# 387  2023-08  0.021717  3.159075 2023-08-01
# 388  2023-09  0.022530  3.181605 2023-09-01
# 389  2023-10  0.042316  3.223921 2023-10-01
# 390  2023-11 -0.030809  3.193112 2023-11-01
# 391  2023-12  0.014298  3.207410 2023-12-01
#
# [392 rows x 4 columns]

# %%
bmk = yf.download('^GSPC', start=start, end=end)

bmk = bmk.reset_index()

bmk = bmk.rename(columns={'Date': 'caldt', 'Adj Close': 'prc'})

bmk = bmk[['caldt', 'prc']]

bmk['mdt'] = bmk['caldt'].dt.strftime("%Y-%m")

bmk = bmk.groupby('mdt').agg({'prc': 'first'}).reset_index()

bmk['caldt'] = pd.to_datetime(bmk['mdt'])

bmk['ret'] = bmk['prc'].pct_change()
bmk['log_ret'] = np.log(1 + bmk['ret'])
bmk['cum_ret'] = bmk['log_ret'].cumsum()

bmk
# Out:
# [*********************100%***********************]  1 of 1 completed
#          mdt          prc      caldt       ret   log_ret   cum_ret
# 0    1990-04   330.799988 1990-04-01       NaN       NaN       NaN
# 1    1990-05   332.250000 1990-05-01  0.004383  0.004374  0.004374
# 2    1990-06   363.160004 1990-06-01  0.093032  0.088956  0.093330
# 3    1990-07   359.540009 1990-07-01 -0.009968 -0.010018  0.083312
# 4    1990-08   355.519989 1990-08-01 -0.011181 -0.011244  0.072068
# ..       ...          ...        ...       ...       ...       ...
# 410  2024-06  5283.399902 2024-06-01  0.052808  0.051461  2.770811
# 411  2024-07  5475.089844 2024-07-01  0.036282  0.035639  2.806450
# 412  2024-08  5446.680176 2024-08-01 -0.005189 -0.005202  2.801248
# 413  2024-09  5528.930176 2024-09-01  0.015101  0.014988  2.816236
# 414  2024-10  5708.750000 2024-10-01  0.032523  0.032006  2.848241
#
# [415 rows x 6 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(backtest_m['caldt'], backtest_m['cum_ret'] * 100, label='Contrarian Strategy')
plt.plot(bmk['caldt'], bmk['cum_ret'] * 100, label='S&P 500 (^GSPC)')
plt.title(f"Out of Sample Backtest ({start} - {end})")
plt.ylabel("Cummulative Log Return (%)")
plt.legend()
plt.show()

# %%
# Calculate sharpe ratio using monthly returns

numerator = backtest_m['log_ret'].mean()
denominator = backtest_m['log_ret'].std()
scale = 12 / np.sqrt(12)

sharpe = numerator / denominator * scale

print(f"Sharpe Ratio of {round(sharpe,2)}")
# Out:
# Sharpe Ratio of 0.64

# %% [markdown]
# ### 5 Factor Model Decomposition

# %%
fac = pd.read_csv("~/Data/fama_5_factors.csv")

fac['mdt'] = pd.to_datetime(fac['DATE'].astype(str), format='%Y%m').dt.strftime("%Y-%m")

fac
# Out:
#        DATE  Mkt-RF   SMB   HML   RMW   CMA    RF      mdt
# 0    196307   -0.39 -0.41 -0.97  0.68 -1.18  0.27  1963-07
# 1    196308    5.07 -0.80  1.80  0.36 -0.35  0.25  1963-08
# 2    196309   -1.57 -0.52  0.13 -0.71  0.29  0.27  1963-09
# 3    196310    2.53 -1.39 -0.10  2.80 -2.01  0.29  1963-10
# 4    196311   -0.85 -0.88  1.75 -0.51  2.24  0.27  1963-11
# ..      ...     ...   ...   ...   ...   ...   ...      ...
# 729  202404   -4.67 -2.56 -0.52  1.48 -0.30  0.47  2024-04
# 730  202405    4.34  0.76 -1.66  2.98 -3.07  0.44  2024-05
# 731  202406    2.77 -4.37 -3.31  0.51 -1.78  0.41  2024-06
# 732  202407    1.24  8.28  5.73  0.22  0.43  0.45  2024-07
# 733  202408    1.61 -3.65 -1.12  0.85  0.86  0.48  2024-08
#
# [734 rows x 8 columns]

# %%
merge = pd.merge(backtest_m, fac, on='mdt', how='inner')

merge = merge.drop(columns=['cum_ret', 'caldt', 'DATE'])

merge['log_ret'] = merge['log_ret'] * 100

merge = merge.rename(columns={'Mkt-RF': 'MKT'})

merge
# Out:
#          mdt   log_ret   MKT   SMB   HML   RMW   CMA    RF
# 0    1991-05 -0.295518  3.65  0.14 -0.52  2.00 -2.43  0.47
# 1    1991-06  4.158578 -4.94  0.24  1.15  1.79  0.65  0.42
# 2    1991-07 -1.625954  4.24 -0.96 -1.32  1.60 -1.36  0.49
# 3    1991-08 -1.884203  2.32  1.40 -0.78  0.84 -0.34  0.46
# 4    1991-09 -2.018661 -1.59  1.56 -1.08 -1.82  0.08  0.46
# ..       ...       ...   ...   ...   ...   ...   ...   ...
# 387  2023-08  2.171695 -2.39 -3.68 -1.08  3.42 -2.37  0.45
# 388  2023-09  2.253046 -5.24 -1.79  1.45  1.85 -0.84  0.43
# 389  2023-10  4.231584 -3.18 -4.05  0.19  2.47 -0.67  0.47
# 390  2023-11 -3.080900  8.83 -0.11  1.66 -3.81 -0.99  0.44
# 391  2023-12  1.429793  4.87  7.33  4.92 -3.04  1.30  0.43
#
# [392 rows x 8 columns]

# %%
model = smf.ols("log_ret ~ MKT + SMB + HML + RMW + CMA", data=merge).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     350.7
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):          4.33e-141
# Time:                        20:09:16   Log-Likelihood:                -803.05
# No. Observations:                 392   AIC:                             1618.
# Df Residuals:                     386   BIC:                             1642.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6624      0.101      6.583      0.000       0.465       0.860
# MKT           -0.2593      0.025    -10.562      0.000      -0.308      -0.211
# SMB           -0.0584      0.036     -1.626      0.105      -0.129       0.012
# HML            0.6882      0.041     16.828      0.000       0.608       0.769
# RMW            0.2561      0.045      5.677      0.000       0.167       0.345
# CMA            0.5806      0.062      9.427      0.000       0.460       0.702
# ==============================================================================
# Omnibus:                       17.253   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.408
# Skew:                           0.145   Prob(JB):                     2.77e-09
# Kurtosis:                       4.526   Cond. No.                         5.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols("log_ret ~ MKT", data=merge).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_ret   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     105.0
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):           5.54e-22
# Time:                        20:09:16   Log-Likelihood:                -1092.0
# No. Observations:                 392   AIC:                             2188.
# Df Residuals:                     390   BIC:                             2196.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1527      0.201      5.727      0.000       0.757       1.548
# MKT           -0.4610      0.045    -10.248      0.000      -0.549      -0.373
# ==============================================================================
# Omnibus:                       30.514   Durbin-Watson:                   1.467
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.009
# Skew:                           0.059   Prob(JB):                     7.16e-28
# Kurtosis:                       5.764   Cond. No.                         4.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
